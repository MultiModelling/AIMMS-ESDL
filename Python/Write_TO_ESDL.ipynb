# %%
DB = "TESTDB_ESDL_to_AIMMS"

Filename = <<Your_ESDL>>
Outputfile = <<Your_Output>>
Host = <<Your_Host>>
User = <<Your_User>>
PW = <<Your_Password>>

from esdl.esdl_handler import EnergySystemHandler
from esdl import esdl
import pymysql
import pandas as pd
import warnings
warnings.filterwarnings("ignore", message= ".*pandas only support SQLAlchemy connectable.*")



conn = pymysql.connect(
    host= Host,
    user=User,
    password=PW)
cursor = conn.cursor()



def get_sql(query):
    try:
        result = pd.read_sql(query, conn)
        return result
    except pymysql.Error as e:
        print("Error: unable to fetch data %d: %s" %(e.args[0], e.args[1]))

class SQLESDL:
    def __init__(self, DB):
        self.tables = get_sql("Select table_schema as database_name, table_name from information_schema.tables where table_type = 'BASE TABLE'and table_schema = '" + DB + "' order by database_name, table_name;")
        self.DB= DB
        
        for i in self.tables.table_name:
            setattr(self, i,get_sql('SELECT * FROM '+DB+'.'+i+ ';'))

    
    def getAttributes(self):    
        return dir(self)


    
 
if __name__ == "__main__":
    Schema = DB
    Training = SQLESDL(Schema)
    print(Training.getAttributes())
    print(Training.Assets)
# Out:
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# ['Arcs', 'Assets', 'Carriers', 'Commodities', 'Constraints', 'ConsumerProfiles', 'Consumers', 'CostInformations', 'DB', 'ElectricityCommodities', 'Producers', 'QuantityAndUnitTypes', 'Transports', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'getAttributes', 'tables']
#                                      id aggregated aggregationCount assetType  \
# 0  1907945a-5ffe-4c08-b9ce-9bc8689f943c          0                1      None
# 1  2f528ef6-186e-4937-9967-d277f78e858a          0                1      None
# 2  80e36970-0f1d-41f4-b371-f380ee3da8d3          0                1      None
# 3  bf483dd9-1f4e-4af1-9b23-ebf5eeae16d3          0                1      None
# 4  ef9b714e-ba35-4efb-9fbd-ff614af32c67          0                1      None
#
#   commissioningDate decommissioningDate description installationDuration  \
# 0              None                None        None                    0
# 1              None                None        None                    0
# 2              None                None        None                    0
# 3              None                None        None                    0
# 4              None                None        None                    0
#
#   manufacturer                     name originalIdInSource owner shortName  \
# 0         None      PVInstallation_1907               None  None      None
# 1         None   ElectricityDemand_2f52               None  None      None
# 2         None  ElectricityNetwork_80e3               None  None      None
# 3         None              Import_bf48               None  None      None
# 4         None              Export_ef9b               None  None      None
#
#       state surfaceArea technicalLifetime  \
# 0  OPTIONAL        7979                 0
# 1   ENABLED           0                 0
# 2   ENABLED           0                 0
# 3   ENABLED           0                 0
# 4   ENABLED           0                 0
#
#                                   costInformation_id
# 0  <esdl.esdl.CostInformation object at 0x0000027...
# 1                                               None
# 2                                               None
# 3  <esdl.esdl.CostInformation object at 0x0000027...
# 4  <esdl.esdl.CostInformation object at 0x0000027...
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)

# %%
def OutputESDL(Schema):
    Training = SQLESDL(Schema)
    esh = EnergySystemHandler()
    es = esh.load_file(Filename)
    asset = esh.get_all_instances_of_type(esdl.Asset)
    proj = []
    for a in asset:
        if a.state.value == 2:
#             kpiwasoptional = esdl.IntKPI(name = 'TEACOS_was_optional',value = 1)
#             a.kpi = kpiwasoptional
#             print(a.name, a.kpi.name)
            proj.append(a.id)
    
    df = Training.Assets
    df = df[df['id'].isin(proj)]
    print(df)
    for i,row in df.iterrows():
        changables = esh.get_by_id(row.id)
        changables.state = row.state
#         print(changables.name, changables.state, row.state)
    
    
    esh.save_as(Outputfile)

    
    
if __name__ == "__main__":
    OutputESDL(DB)
# Out:
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
#                                      id aggregated aggregationCount assetType  \
# 0  1907945a-5ffe-4c08-b9ce-9bc8689f943c          0                1      None
#
#   commissioningDate decommissioningDate description installationDuration  \
# 0              None                None        None                    0
#
#   manufacturer                 name originalIdInSource owner shortName  \
# 0         None  PVInstallation_1907               None  None      None
#
#       state surfaceArea technicalLifetime  \
# 0  OPTIONAL        7979                 0
#
#                                   costInformation_id
# 0  <esdl.esdl.CostInformation object at 0x0000027...
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_1620\2983440658.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query, conn)
